-- %% [markdown]
-- # <span style="font-size: 20pt; font-family: Montserrat, sans-serif; color: rgb(92, 148, 206); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Graded Assignment 3: 9 to 5</span>
--
--
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Time to show off your SQL skills! For each question, copy the SQL query you used and make note of the answer.</span>
--
--
--
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">The Dataset</span>
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">For this assignment, you will be using the Bureau of Labor Statistics (BLS) Current Employment Survey (CES) results which can be found on</span> [<span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(17, 85, 204); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; text-decoration-line: underline; vertical-align: baseline; white-space: pre-wrap;">Kaggle</span>](https://www.kaggle.com/bls/employment)<span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">.</span>
--
--
--
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Business Issue</span>
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">You are working for the Bureau of Labor Statistics with the United States government and have been approached by your boss with an important meeting request. You have been asked by your supervisor to meet with Dolly Parton whose nonprofit is looking to shed light on the state of employment in the United States. As part of the 9 to 5 project, their research is focused on production and nonsupervisory employees and how those employees fare compared to all employees in the United States. While the data the BLS collects from the CES is publicly available, Dolly Parton and her colleagues need your assistance navigating the thousands of rows in each table in LaborStatisticsDB.</span>
--
--
--
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">About the Dataset</span>
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">This dataset comes directly from the Bureau of Labor Statistics’ Current Employment Survey (CES). Here are some things you need to know:</span>
--
-- 1. <span style="font-size: 10pt; background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">The industry table contains an NAICS code. This is different from the industry code. NAICS stands for North American Industry Classification System.</span>
--
-- 2. <span style="font-size: 10pt; background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Series ID is composed of multiple different codes. CES stands for Current Employment Survey, the name of the survey which collected the data. The industry code as specified by the BLS and the data type code as specified in the datatype table.</span>
--
--
--
--
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Set Up</span>
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">To connect to the database, use the same connection info used during the SQL lessons.&nbsp;</span>
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">For the assignment, we will be using the LaborStatisticsDB database.</span>
--
--
--
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Database Exploration</span>
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">To start with, let’s get to know the database further.</span>
--
-- 1. <span style="background-color: rgb(255, 255, 255); color: rgb(102, 102, 102); font-family: &quot;Times New Roman&quot;; font-size: 10pt; white-space: pre-wrap;">Use this space to make note of each table in the database, the columns within each table, each column’s data type, and how the tables are connected. You can write this down or draw a diagram. Whatever method helps you get an understanding of what is going on with LaborStatisticsDB.</span>

-- %% [markdown]
-- To add a photo, diagram or document to your file, drop the file into the folder that holds this notebook.  Use the the link button to the right of the  \</\> symbol in the gray part of this cell, the link is just the name of your file.

-- %%
USE LaborStatisticsDB
GO
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.056

-- %% [markdown]
-- 2. <span style="background-color: rgb(255, 255, 255); color: rgb(102, 102, 102); font-family: Arvo, serif; font-size: 10pt; white-space: pre-wrap;">What is the datatype for women employees?</span>

-- %%
SELECT * 
FROM LaborStatisticsDB.dbo.datatype
WHERE data_type_text = 'WOMEN EMPLOYEES'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.113
-- <table><tr><th>data_type_code</th><th>data_type_text</th></tr><tr><td>10</td><td>WOMEN EMPLOYEES</td></tr></table>

-- %% [markdown]
-- 3. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">What is the series id for&nbsp; women employees in the commercial banking industry in the financial activities supersector?</span>

-- %%
SELECT series_id
FROM LaborStatisticsDB.dbo.series
WHERE data_type_code = 10 AND supersector_code = 55
-- Out:
-- (118 rows affected)
-- Total execution time: 00:00:00.078
-- <table><tr><th>series_id</th></tr><tr><td>CES5500000010</td></tr><tr><td>CES5552200010</td></tr><tr><td>CES5552210010</td></tr><tr><td>CES5552211010</td></tr><tr><td>CES5552212010</td></tr><tr><td>CES5552219010</td></tr><tr><td>CES5552220010</td></tr><tr><td>CES5552221010</td></tr><tr><td>CES5552222010</td></tr><tr><td>CES5552229010</td></tr><tr><td>CES5552229110</td></tr><tr><td>CES5552229210</td></tr><tr><td>CES5552229810</td></tr><tr><td>CES5552230010</td></tr><tr><td>CES5552231010</td></tr><tr><td>CES5552232010</td></tr><tr><td>CES5552239010</td></tr><tr><td>CES5552300010</td></tr><tr><td>CES5552312010</td></tr><tr><td>CES5552320010</td></tr><tr><td>CES5552390010</td></tr><tr><td>CES5552391010</td></tr><tr><td>CES5552392010</td></tr><tr><td>CES5552393010</td></tr><tr><td>CES5552399010</td></tr><tr><td>CES5552400010</td></tr><tr><td>CES5552410010</td></tr><tr><td>CES5552411010</td></tr><tr><td>CES5552412010</td></tr><tr><td>CES5552412610</td></tr><tr><td>CES5552412810</td></tr><tr><td>CES5552413010</td></tr><tr><td>CES5552420010</td></tr><tr><td>CES5552421010</td></tr><tr><td>CES5552429010</td></tr><tr><td>CES5552429110</td></tr><tr><td>CES5552429210</td></tr><tr><td>CES5552429810</td></tr><tr><td>CES5553100010</td></tr><tr><td>CES5553110010</td></tr><tr><td>CES5553111010</td></tr><tr><td>CES5553112010</td></tr><tr><td>CES5553113010</td></tr><tr><td>CES5553119010</td></tr><tr><td>CES5553120010</td></tr><tr><td>CES5553130010</td></tr><tr><td>CES5553131010</td></tr><tr><td>CES5553131110</td></tr><tr><td>CES5553131210</td></tr><tr><td>CES5553132010</td></tr><tr><td>CES5553139010</td></tr><tr><td>CES5553200010</td></tr><tr><td>CES5553210010</td></tr><tr><td>CES5553220010</td></tr><tr><td>CES5553229110</td></tr><tr><td>CES5553230010</td></tr><tr><td>CES5553240010</td></tr><tr><td>CES5553241010</td></tr><tr><td>CES5553249010</td></tr><tr><td>CEU5500000010</td></tr><tr><td>CEU5552200010</td></tr><tr><td>CEU5552210010</td></tr><tr><td>CEU5552211010</td></tr><tr><td>CEU5552212010</td></tr><tr><td>CEU5552219010</td></tr><tr><td>CEU5552220010</td></tr><tr><td>CEU5552221010</td></tr><tr><td>CEU5552222010</td></tr><tr><td>CEU5552229010</td></tr><tr><td>CEU5552229110</td></tr><tr><td>CEU5552229210</td></tr><tr><td>CEU5552229810</td></tr><tr><td>CEU5552230010</td></tr><tr><td>CEU5552231010</td></tr><tr><td>CEU5552232010</td></tr><tr><td>CEU5552239010</td></tr><tr><td>CEU5552300010</td></tr><tr><td>CEU5552312010</td></tr><tr><td>CEU5552320010</td></tr><tr><td>CEU5552390010</td></tr><tr><td>CEU5552391010</td></tr><tr><td>CEU5552392010</td></tr><tr><td>CEU5552393010</td></tr><tr><td>CEU5552399010</td></tr><tr><td>CEU5552400010</td></tr><tr><td>CEU5552410010</td></tr><tr><td>CEU5552411010</td></tr><tr><td>CEU5552412010</td></tr><tr><td>CEU5552412610</td></tr><tr><td>CEU5552412810</td></tr><tr><td>CEU5552413010</td></tr><tr><td>CEU5552420010</td></tr><tr><td>CEU5552421010</td></tr><tr><td>CEU5552429010</td></tr><tr><td>CEU5552429110</td></tr><tr><td>CEU5552429210</td></tr><tr><td>CEU5552429810</td></tr><tr><td>CEU5553100010</td></tr><tr><td>CEU5553110010</td></tr><tr><td>CEU5553111010</td></tr><tr><td>CEU5553112010</td></tr><tr><td>CEU5553113010</td></tr><tr><td>CEU5553119010</td></tr><tr><td>CEU5553120010</td></tr><tr><td>CEU5553130010</td></tr><tr><td>CEU5553131010</td></tr><tr><td>CEU5553131110</td></tr><tr><td>CEU5553131210</td></tr><tr><td>CEU5553132010</td></tr><tr><td>CEU5553139010</td></tr><tr><td>CEU5553200010</td></tr><tr><td>CEU5553210010</td></tr><tr><td>CEU5553220010</td></tr><tr><td>CEU5553229110</td></tr><tr><td>CEU5553230010</td></tr><tr><td>CEU5553240010</td></tr><tr><td>CEU5553241010</td></tr><tr><td>CEU5553249010</td></tr></table>

-- %% [markdown]
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-numeric: normal; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Join in on the Fun</span>
--
-- <span style="font-size: 10pt; font-family: Arvo, serif; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-numeric: normal; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Time to start joining! You can choose the type of join you use, just make sure to make a&nbsp; note!</span>
--
-- 1. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">Join&nbsp; annual_2016 with series on series_id. We only want the data in the annual_2016 table to be included in the result.</span>

-- %%
SELECT a.series_id
FROM LaborStatisticsDB.dbo.annual_2016 AS a
INNER JOIN LaborStatisticsDB.dbo.series AS s ON s.series_id = a.series_id
-- Out:
-- (29042 rows affected)
-- Displaying Top 5000 rows.
-- Total execution time: 00:00:00.551
-- <table><tr><th>series_id</th></tr><tr><td>CEU5500000007</td></tr><tr><td>CEU5500000008</td></tr><tr><td>CEU5500000030</td></tr><tr><td>CEU5500000031</td></tr><tr><td>CEU5500000032</td></tr><tr><td>CEU5500000034</td></tr><tr><td>CEU5500000035</td></tr><tr><td>CEU5500000081</td></tr><tr><td>CEU5500000082</td></tr><tr><td>CEU5552200007</td></tr><tr><td>CEU5552200008</td></tr><tr><td>CEU5552200030</td></tr><tr><td>CEU5552200031</td></tr><tr><td>CEU5552200032</td></tr><tr><td>CEU5552200034</td></tr><tr><td>CEU5552200035</td></tr><tr><td>CEU5552200081</td></tr><tr><td>CEU5552200082</td></tr><tr><td>CEU5552210007</td></tr><tr><td>CEU5552210008</td></tr><tr><td>CEU5552210030</td></tr><tr><td>CEU5552210031</td></tr><tr><td>CEU5552210032</td></tr><tr><td>CEU5552210034</td></tr><tr><td>CEU5552210035</td></tr><tr><td>CEU5552210081</td></tr><tr><td>CEU5552210082</td></tr><tr><td>CEU5552211007</td></tr><tr><td>CEU5552211008</td></tr><tr><td>CEU5552211030</td></tr><tr><td>CEU5552211031</td></tr><tr><td>CEU5552211032</td></tr><tr><td>CEU5552211034</td></tr><tr><td>CEU5552211035</td></tr><tr><td>CEU5552211081</td></tr><tr><td>CEU5552211082</td></tr><tr><td>CEU5552212007</td></tr><tr><td>CEU5552212008</td></tr><tr><td>CEU5552212030</td></tr><tr><td>CEU5552212031</td></tr><tr><td>CEU5552212032</td></tr><tr><td>CEU5552212034</td></tr><tr><td>CEU5552212035</td></tr><tr><td>CEU5552212081</td></tr><tr><td>CEU5552212082</td></tr><tr><td>CEU5552219007</td></tr><tr><td>CEU5552219008</td></tr><tr><td>CEU5552219030</td></tr><tr><td>CEU5552219031</td></tr><tr><td>CEU5552219032</td></tr><tr><td>CEU5552219034</td></tr><tr><td>CEU5552219035</td></tr><tr><td>CEU5552219081</td></tr><tr><td>CEU5552219082</td></tr><tr><td>CEU5552220007</td></tr><tr><td>CEU5552220008</td></tr><tr><td>CEU5552220030</td></tr><tr><td>CEU5552220031</td></tr><tr><td>CEU5552220032</td></tr><tr><td>CEU5552220034</td></tr><tr><td>CEU5552220035</td></tr><tr><td>CEU5552220081</td></tr><tr><td>CEU5552220082</td></tr><tr><td>CEU5552229107</td></tr><tr><td>CEU5552229108</td></tr><tr><td>CEU5552229130</td></tr><tr><td>CEU5552229131</td></tr><tr><td>CEU5552229132</td></tr><tr><td>CEU5552229134</td></tr><tr><td>CEU5552229135</td></tr><tr><td>CEU5552229181</td></tr><tr><td>CEU5552229182</td></tr><tr><td>CEU5552229207</td></tr><tr><td>CEU5552229208</td></tr><tr><td>CEU5552229230</td></tr><tr><td>CEU5552229231</td></tr><tr><td>CEU5552229232</td></tr><tr><td>CEU5552229234</td></tr><tr><td>CEU5552229235</td></tr><tr><td>CEU5552229281</td></tr><tr><td>CEU5552229282</td></tr><tr><td>CEU5552230007</td></tr><tr><td>CEU5552230008</td></tr><tr><td>CEU5552230030</td></tr><tr><td>CEU5552230031</td></tr><tr><td>CEU5552230032</td></tr><tr><td>CEU5552230034</td></tr><tr><td>CEU5552230035</td></tr><tr><td>CEU5552230081</td></tr><tr><td>CEU5552230082</td></tr><tr><td>CEU5552232007</td></tr><tr><td>CEU5552232008</td></tr><tr><td>CEU5552232030</td></tr><tr><td>CEU5552232031</td></tr><tr><td>CEU5552232032</td></tr><tr><td>CEU5552232034</td></tr><tr><td>CEU5552232035</td></tr><tr><td>CEU5552232081</td></tr><tr><td>CEU5552232082</td></tr><tr><td>CEU5552300007</td></tr><tr><td>CEU5552300008</td></tr><tr><td>CEU5552300030</td></tr><tr><td>CEU5552300031</td></tr><tr><td>CEU5552300032</td></tr><tr><td>CEU5552300034</td></tr><tr><td>CEU5552300035</td></tr><tr><td>CEU5552300081</td></tr><tr><td>CEU5552300082</td></tr><tr><td>CEU5552312007</td></tr><tr><td>CEU5552312008</td></tr><tr><td>CEU5552312030</td></tr><tr><td>CEU5552312031</td></tr><tr><td>CEU5552312032</td></tr><tr><td>CEU5552312034</td></tr><tr><td>CEU5552312035</td></tr><tr><td>CEU5552312081</td></tr><tr><td>CEU5552312082</td></tr><tr><td>CEU5552320007</td></tr><tr><td>CEU5552320008</td></tr><tr><td>CEU5552320030</td></tr><tr><td>CEU5552320031</td></tr><tr><td>CEU5552320032</td></tr><tr><td>CEU5552320034</td></tr><tr><td>CEU5552320035</td></tr><tr><td>CEU5552320081</td></tr><tr><td>CEU5552320082</td></tr><tr><td>CEU5552390007</td></tr><tr><td>CEU5552390008</td></t ...

-- %% [markdown]
-- 2. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">Join series and datatype on data_type_code</span>

-- %%
SELECT *
FROM LaborStatisticsDB.dbo.series AS s
INNER JOIN LaborStatisticsDB.dbo.datatype AS d ON d.data_type_code = s.data_type_code
-- Out:
-- (26709 rows affected)
-- Displaying Top 5000 rows.
-- Total execution time: 00:00:01.770
-- <table><tr><th>series_id</th><th>supersector_code</th><th>industry_code</th><th>data_type_code</th><th>seasonal</th><th>series_title</th><th>data_type_code</th><th>data_type_text</th></tr><tr><td>CES0000000001</td><td>0</td><td>00000000</td><td>1</td><td>S</td><td>All employees</td><td>1</td><td>ALL EMPLOYEES</td></tr><tr><td>CES0000000010</td><td>0</td><td>00000000</td><td>10</td><td>S</td><td>Women employees</td><td>10</td><td>WOMEN EMPLOYEES</td></tr><tr><td>CES0000000025</td><td>0</td><td>00000000</td><td>25</td><td>S</td><td>All employees</td><td>25</td><td>ALL EMPLOYEES</td></tr><tr><td>CES0000000026</td><td>0</td><td>00000000</td><td>26</td><td>S</td><td>All employees</td><td>26</td><td>ALL EMPLOYEES</td></tr><tr><td>CES0500000001</td><td>5</td><td>05000000</td><td>1</td><td>S</td><td>All employees</td><td>1</td><td>ALL EMPLOYEES</td></tr><tr><td>CES0500000002</td><td>5</td><td>05000000</td><td>2</td><td>S</td><td>Average weekly hours of all employees</td><td>2</td><td>AVERAGE WEEKLY HOURS OF ALL EMPLOYEES</td></tr><tr><td>CES0500000003</td><td>5</td><td>05000000</td><td>3</td><td>S</td><td>Average hourly earnings of all employees</td><td>3</td><td>AVERAGE HOURLY EARNINGS OF ALL EMPLOYEES</td></tr><tr><td>CES0500000006</td><td>5</td><td>05000000</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td><td>6</td><td>PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr><tr><td>CES0500000007</td><td>5</td><td>05000000</td><td>7</td><td>S</td><td>Average weekly hours of production and nonsupervisory employees</td><td>7</td><td>AVERAGE WEEKLY HOURS OF PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr><tr><td>CES0500000008</td><td>5</td><td>05000000</td><td>8</td><td>S</td><td>Average hourly earnings of production and nonsupervisory employees</td><td>8</td><td>AVERAGE HOURLY EARNINGS OF PRODUCTION AND NONSUPERVISORY EMPLOYEES</td></tr><tr><td>CES0500000010</td><td>5</td><td>05000000</td><td>10</td><td>S</td><td>Women employees</td><td>10</td><td>WOMEN EMPLOYEES</td></tr><tr><td>CES0500000011</td><td>5</td><td>05000000</td><td>11</td><td>S</td><td>Average weekly earnings of all employees</td><td>11</td><td>AVERAGE WEEKLY EARNINGS OF ALL EMPLOYEES</td></tr><tr><td>CES0500000012</td><td>5</td><td>05000000</td><td>12</td><td>S</td><td>Average weekly earnings of all employees</td><td>12</td><td>AVERAGE WEEKLY EARNINGS OF ALL EMPLOYEES</td></tr><tr><td>CES0500000013</td><td>5</td><td>05000000</td><td>13</td><td>S</td><td>Average hourly earnings of all employees</td><td>13</td><td>AVERAGE HOURLY EARNINGS OF ALL EMPLOYEES</td></tr><tr><td>CES0500000016</td><td>5</td><td>05000000</td><td>16</td><td>S</td><td>Indexes of aggregate weekly hours of all employees</td><td>16</td><td>INDEXES OF AGGREGATE WEEKLY HOURS OF ALL EMPLOYEES</td></tr><tr><td>CES0500000017</td><td>5</td><td>05000000</td><td>17</td><td>S</td><td>Indexes of aggregate weekly payrolls of all employees</td><td>17</td><td>INDEXES OF AGGREGATE WEEKLY PAYROLLS OF ALL EMPLOYEES</td></tr><tr><td>CES0500000019</td><td>5</td><td>05000000</td><td>19</td><td>S</td><td>Average weekly hours of all employees</td><td>19</td><td>AVERAGE WEEKLY HOURS OF ALL EMPLOYEES</td></tr><tr><td>CES0500000021</td><td>5</td><td>05000000</td><td>21</td><td>S</td><td>Diffusion indexes</td><td>21</td><td>DIFFUSION INDEXES</td></tr><tr><td>CES0500000022</td><td>5</td><td>05000000</td><td>22</td><td>S</td><td>Diffusion indexes</td><td>22</td><td>DIFFUSION INDEXES</td></tr><tr><td>CES0500000023</td><td>5</td><td>05000000</td><td>23</td><td>S</td><td>Diffusion indexes</td><td>23</td><td>DIFFUSION INDEXES</td></tr><tr><td>CES0500000025</td><td>5</td><td>05000000</td><td>25</td><td>S</td><td>All employees</td><td>25</td><td>ALL EMPLOYEES</td></tr><tr><td>CES0500000026</td><td>5</td><td>05000000</td><td>26</td><td>S</td><td>All employees</td><td>26</td><td>ALL EMPLOYEES</td></tr><tr><td>CES0500000030</td><td>5</td><td>05000000</td><td>30</td><td>S</td><td>Average weekly earnings of production and no ...

-- %% [markdown]
-- 3. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">Join series and industry on industry_code</span>

-- %%
SELECT *
FROM LaborStatisticsDB.dbo.series AS s
INNER JOIN LaborStatisticsDB.dbo.industry AS i ON i.industry_code = s.industry_code

-- %% [markdown]
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-numeric: normal; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Aggregate Your Friends and Code some SQL</span>
--
-- <span style="font-size: 10pt; font-family: Arvo, serif; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-numeric: normal; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Put together the following:</span>
--
-- 1. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">How many employees were reported in 2016 in all industries? Round to the nearest whole number.&nbsp; No chopping people into little bits, please.</span>

-- %%
SELECT COUNT(id) AS NumberOfEmployees
FROM LaborStatisticsDB.dbo.annual_2016
-- Out:
-- Query was canceled by user
-- Query was canceled by user
-- Total execution time: 00:00:00.601
-- <table><tr><th>series_id</th><th>supersector_code</th><th>industry_code</th><th>data_type_code</th><th>seasonal</th><th>series_title</th><th>id</th><th>industry_code</th><th>naics_code</th><th>publishing_status</th><th>industry_name</th><th>display_level</th><th>selectable</th><th>sort_sequence</th></tr><tr><td>CES0000000001</td><td>0</td><td>00000000</td><td>1</td><td>S</td><td>All employees</td><td>0</td><td>0</td><td>-</td><td>B</td><td>Total nonfarm</td><td>0</td><td>T</td><td>1</td></tr><tr><td>CES0000000010</td><td>0</td><td>00000000</td><td>10</td><td>S</td><td>Women employees</td><td>0</td><td>0</td><td>-</td><td>B</td><td>Total nonfarm</td><td>0</td><td>T</td><td>1</td></tr><tr><td>CES0000000025</td><td>0</td><td>00000000</td><td>25</td><td>S</td><td>All employees</td><td>0</td><td>0</td><td>-</td><td>B</td><td>Total nonfarm</td><td>0</td><td>T</td><td>1</td></tr><tr><td>CES0000000026</td><td>0</td><td>00000000</td><td>26</td><td>S</td><td>All employees</td><td>0</td><td>0</td><td>-</td><td>B</td><td>Total nonfarm</td><td>0</td><td>T</td><td>1</td></tr><tr><td>CES0500000001</td><td>5</td><td>05000000</td><td>1</td><td>S</td><td>All employees</td><td>1</td><td>5000000</td><td>-</td><td>A</td><td>Total private</td><td>1</td><td>T</td><td>2</td></tr><tr><td>CES0500000002</td><td>5</td><td>05000000</td><td>2</td><td>S</td><td>Average weekly hours of all employees</td><td>1</td><td>5000000</td><td>-</td><td>A</td><td>Total private</td><td>1</td><td>T</td><td>2</td></tr><tr><td>CES0500000003</td><td>5</td><td>05000000</td><td>3</td><td>S</td><td>Average hourly earnings of all employees</td><td>1</td><td>5000000</td><td>-</td><td>A</td><td>Total private</td><td>1</td><td>T</td><td>2</td></tr><tr><td>CES0500000006</td><td>5</td><td>05000000</td><td>6</td><td>S</td><td>Production and nonsupervisory employees</td><td>1</td><td>5000000</td><td>-</td><td>A</td><td>Total private</td><td>1</td><td>T</td><td>2</td></tr><tr><td>CES0500000007</td><td>5</td><td>05000000</td><td>7</td><td>S</td><td>Average weekly hours of production and nonsupervisory employees</td><td>1</td><td>5000000</td><td>-</td><td>A</td><td>Total private</td><td>1</td><td>T</td><td>2</td></tr><tr><td>CES0500000008</td><td>5</td><td>05000000</td><td>8</td><td>S</td><td>Average hourly earnings of production and nonsupervisory employees</td><td>1</td><td>5000000</td><td>-</td><td>A</td><td>Total private</td><td>1</td><td>T</td><td>2</td></tr><tr><td>CES0500000010</td><td>5</td><td>05000000</td><td>10</td><td>S</td><td>Women employees</td><td>1</td><td>5000000</td><td>-</td><td>A</td><td>Total private</td><td>1</td><td>T</td><td>2</td></tr><tr><td>CES0500000011</td><td>5</td><td>05000000</td><td>11</td><td>S</td><td>Average weekly earnings of all employees</td><td>1</td><td>5000000</td><td>-</td><td>A</td><td>Total private</td><td>1</td><td>T</td><td>2</td></tr><tr><td>CES0500000012</td><td>5</td><td>05000000</td><td>12</td><td>S</td><td>Average weekly earnings of all employees</td><td>1</td><td>5000000</td><td>-</td><td>A</td><td>Total private</td><td>1</td><td>T</td><td>2</td></tr><tr><td>CES0500000013</td><td>5</td><td>05000000</td><td>13</td><td>S</td><td>Average hourly earnings of all employees</td><td>1</td><td>5000000</td><td>-</td><td>A</td><td>Total private</td><td>1</td><td>T</td><td>2</td></tr><tr><td>CES0500000016</td><td>5</td><td>05000000</td><td>16</td><td>S</td><td>Indexes of aggregate weekly hours of all employees</td><td>1</td><td>5000000</td><td>-</td><td>A</td><td>Total private</td><td>1</td><td>T</td><td>2</td></tr><tr><td>CES0500000017</td><td>5</td><td>05000000</td><td>17</td><td>S</td><td>Indexes of aggregate weekly payrolls of all employees</td><td>1</td><td>5000000</td><td>-</td><td>A</td><td>Total private</td><td>1</td><td>T</td><td>2</td></tr><tr><td>CES0500000019</td><td>5</td><td>05000000</td><td>19</td><td>S</td><td>Average weekly hours of all employees</td><td>1</td><td>5000000</td><td>-</td><td>A</td><td>Total private</td><td>1</td><t ...

-- %% [markdown]
-- 2. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">How many women employees were reported in 2016 in all industries? Round to the nearest whole number.&nbsp;</span>

-- %%
SELECT COUNT(data_type_code) AS 'Number Of Women Employees'
FROM LaborStatisticsDB.dbo.series
WHERE data_type_code = 10
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.066
-- <table><tr><th>Number Of Women Employees</th></tr><tr><td>1372</td></tr></table>

-- %% [markdown]
-- 3. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">How many production/nonsupervisory employees were reported in 2016? Round to the nearest whole number.&nbsp;</span>

-- %%
SELECT COUNT(series_id) AS 'Number Of Production And Nonsupervisory Employees'
FROM LaborStatisticsDB.dbo.series
WHERE industry_code = 05000000;
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.060
-- <table><tr><th>Number Of Production And Nonsupervisory Employees</th></tr><tr><td>50</td></tr></table>

-- %% [markdown]
-- 4. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">In January 2017, what is the average weekly hours worked by production and nonsupervisory employees across all industries?</span>

-- %%
SELECT AVG(j.value) AS 'Average Weekly Hours'
FROM LaborStatisticsDB.dbo.january_2017 AS j
INNER JOIN LaborStatisticsDB.dbo.series AS s
ON j.series_id = s.series_id
WHERE s.data_type_code = 7;
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.181
-- <table><tr><th>Average Weekly Hours</th></tr><tr><td>36.05862068965521</td></tr></table>

-- %% [markdown]
-- 5. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">What is the total weekly payroll for production and nonsupervisory employees across all industries in January 2017? Round to the nearest penny, please.</span>

-- %%
SELECT SUM(j.value) AS 'Total Weekly Payroll'
FROM LaborStatisticsDB.dbo.january_2017 AS j
INNER JOIN LaborStatisticsDB.dbo.series AS s
ON j.series_id = s.series_id
WHERE s.data_type_code = 82;
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.098
-- <table><tr><th>Total Weekly Payroll</th></tr><tr><td>1838753220</td></tr></table>

-- %% [markdown]
-- 6. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">In January 2017, which industry was the average weekly hours worked by production and nonsupervisory employees the highest? Which industry was the lowest?</span>

-- %%
SELECT SUM(j.value) AS 'Average Weekly Hours', i.industry_name
FROM LaborStatisticsDB.dbo.january_2017 AS j
INNER JOIN LaborStatisticsDB.dbo.series AS s ON j.series_id = s.series_id
INNER JOIN LaborStatisticsDB.dbo.industry AS i ON s.industry_code = i.industry_code
GROUP BY i.industry_name
ORDER BY AVG(j.[value]) DESC;

SELECT SUM(j.value) AS 'Average Weekly Hours', i.industry_name
FROM LaborStatisticsDB.dbo.january_2017 AS j
INNER JOIN LaborStatisticsDB.dbo.series AS s ON j.series_id = s.series_id
INNER JOIN LaborStatisticsDB.dbo.industry AS i ON s.industry_code = i.industry_code
GROUP BY i.industry_name
ORDER BY AVG(j.[value]) ASC;
-- Out:
-- (793 rows affected)
-- (793 rows affected)
-- Total execution time: 00:00:00.308
-- <table><tr><th>Average Weekly Hours</th><th>industry_name</th></tr><tr><td>767581922.4500002</td><td>Total private</td></tr><tr><td>622825712.0500002</td><td>Private service-providing</td></tr><tr><td>159125077.72</td><td>Professional and business services</td></tr><tr><td>151138173.08</td><td>Trade</td></tr><tr><td>143680108.38</td><td>Goods-producing</td></tr><tr><td>143440862.65</td><td>Education and health services</td></tr><tr><td>123508300.02999997</td><td>Health care and social assistance</td></tr><tr><td>92466177.51999997</td><td>Professional and technical services</td></tr><tr><td>69266168.39999999</td><td>Financial activities</td></tr><tr><td>86727031.74000002</td><td>Manufacturing</td></tr><tr><td>63325383.36</td><td>Retail trade</td></tr><tr><td>50933918.789999984</td><td>Construction</td></tr><tr><td>50159765.42</td><td>Ambulatory health care services</td></tr><tr><td>47267285.37999998</td><td>Wholesale trade</td></tr><tr><td>46124621.63999999</td><td>Administrative and waste services</td></tr><tr><td>45335485.589999996</td><td>Hospitals</td></tr><tr><td>44920177.78</td><td>Leisure and hospitality</td></tr><tr><td>43000405.66999999</td><td>Administrative and support services</td></tr><tr><td>42231707.23000001</td><td>General medical and surgical hospitals</td></tr><tr><td>37305575.62</td><td>Accommodation and food services</td></tr><tr><td>80673743.07</td><td>Durable goods</td></tr><tr><td>33904002.37</td><td>Transportation and warehousing</td></tr><tr><td>31771995.11999999</td><td>Specialty trade contractors</td></tr><tr><td>30126331.659999993</td><td>Food services and drinking places</td></tr><tr><td>29829566.569999993</td><td>Other services</td></tr><tr><td>27006801.79999999</td><td>Restaurants and other eating places</td></tr><tr><td>25946520.150000006</td><td>Computer systems design and related services</td></tr><tr><td>25652681.879999988</td><td>Information</td></tr><tr><td>24178232.239999983</td><td>Insurance carriers and related activities</td></tr><tr><td>46363789.599999994</td><td>Offices of physicians</td></tr><tr><td>20771600.63</td><td>Management of companies and enterprises</td></tr><tr><td>20178586.120000005</td><td>Credit intermediation and related activities</td></tr><tr><td>19828586.269999996</td><td>Managing offices</td></tr><tr><td>44071018.53999999</td><td>Nondurable goods</td></tr><tr><td>17731945.309999995</td><td>Employment services</td></tr><tr><td>17095821.889999993</td><td>Membership associations and organizations</td></tr><tr><td>16353242.099999992</td><td>Building equipment contractors</td></tr><tr><td>15621148.169999992</td><td>Full-service restaurants</td></tr><tr><td>15139460.070000002</td><td>Insurance carriers</td></tr><tr><td>14756607.17</td><td>Nursing and residential care facilities</td></tr><tr><td>14751228.629999995</td><td>Architectural and engineering services</td></tr><tr><td>14190242.549999999</td><td>Management and technical consulting services</td></tr><tr><td>13816014.590000002</td><td>Temporary help services</td></tr><tr><td>13455442.810000002</td><td>Social assistance</td></tr><tr><td>12347224.59</td><td>Computer systems design services</td></tr><tr><td>12241397.61</td><td>Depository credit intermediation</td></tr><tr><td>12193458.519999998</td><td>Motor vehicle and parts dealers</td></tr><tr><td>11501855.559999999</td><td>Management consulting services</td></tr><tr><td>11497120.9</td><td>Custom computer programming services</td></tr><tr><td>11405900.249999996</td><td>Legal services</td></tr><tr><td>11217904.070000002</td><td>Construction of buildings</td></tr><tr><td>14094987.94</td><td>Transportation equipment</td></tr><tr><td>10842891.160000006</td><td>Offices of lawyers</td></tr><tr><td>10602372.479999997</td><td>General merchandise stores</td></tr><tr><td>10403587.73</td><td>Truck transportation</td></tr><tr><td>9965054.85</td><td>Food and beverage stores</td></tr><tr><td>9663427.050000003</td><td>Limited-service restaurants</td></tr><tr><td>9619843.120000001</t ...
-- <table><tr><th>Average Weekly Hours</th><th>industry_name</th></tr><tr><td>55.800000000000004</td><td>Video tape and disc rental</td></tr><tr><td>61.5</td><td>Breakfast cereal</td></tr><tr><td>63</td><td>Other nonmetallic mineral mining</td></tr><tr><td>75.5</td><td>Art dealers</td></tr><tr><td>75.6</td><td>Bed-and-breakfast inns</td></tr><tr><td>150.9</td><td>Construction sand and gravel mining</td></tr><tr><td>89.6</td><td>Telephone apparatus</td></tr><tr><td>94</td><td>Monetary authorities - central bank</td></tr><tr><td>99.4</td><td>Other spectator sports</td></tr><tr><td>191.6</td><td>Scenic and sightseeing transportation</td></tr><tr><td>196.20000000000002</td><td>New multifamily general contractors</td></tr><tr><td>197.3</td><td>Automotive glass replacement shops</td></tr><tr><td>110.89999999999999</td><td>Credit bureaus</td></tr><tr><td>113.10000000000001</td><td>Textile bag and canvas mills</td></tr><tr><td>205.69999999999996</td><td>Ornamental and architectural metal work</td></tr><tr><td>115.30000000000001</td><td>Office furniture</td></tr><tr><td>115.4</td><td>Lessors of nonfinancial intangible assets</td></tr><tr><td>119.10000000000001</td><td>Motor vehicle brake systems</td></tr><tr><td>119.3</td><td>Support activities for printing</td></tr><tr><td>121.19999999999999</td><td>Racetracks</td></tr><tr><td>123.5</td><td>Bituminous coal and lignite surface mining</td></tr><tr><td>228.1</td><td>New housing operative builders</td></tr><tr><td>127.69999999999999</td><td>Jewelry and silverware</td></tr><tr><td>128.3</td><td>Broadwoven fabric mills</td></tr><tr><td>234.3</td><td>Machine tool manufacturing</td></tr><tr><td>132.6</td><td>Electric bulk power transmission and control</td></tr><tr><td>132.8</td><td>Electric power and specialty transformers</td></tr><tr><td>242.4</td><td>Vending machine operators</td></tr><tr><td>135.6</td><td>RV parks and campgrounds</td></tr><tr><td>135.7</td><td>Heavy duty trucks</td></tr><tr><td>245.60000000000002</td><td>Clay products and refractories</td></tr><tr><td>137.5</td><td>Bare printed circuit boards</td></tr><tr><td>145</td><td>Tour operators</td></tr><tr><td>145.7</td><td>Fiber</td></tr><tr><td>146</td><td>Paperboard mills</td></tr><tr><td>146.1</td><td>Recreational and vacation camps</td></tr><tr><td>146.20000000000002</td><td>Batteries</td></tr><tr><td>152.6</td><td>Frozen fruits and vegetables</td></tr><tr><td>155.8</td><td>Musical instrument and supplies stores</td></tr><tr><td>156.9</td><td>Textile and fabric finishing mills</td></tr><tr><td>284.1</td><td>Pumps and compressors</td></tr><tr><td>294.7</td><td>Plastics pipe</td></tr><tr><td>165.60000000000002</td><td>Nonupholstered wood household furniture</td></tr><tr><td>167.20000000000002</td><td>Investigation services</td></tr><tr><td>170.3</td><td>Motors and generators</td></tr><tr><td>306.9</td><td>Broadcast and wireless communications equipment</td></tr><tr><td>173.7</td><td>Taxi service</td></tr><tr><td>174.60000000000002</td><td>Agricultural chemicals</td></tr><tr><td>175.89999999999998</td><td>Fluid power valves and hose fittings</td></tr><tr><td>178</td><td>Iron foundries</td></tr><tr><td>178.5</td><td>Offices of podiatrists</td></tr><tr><td>178.8</td><td>Musical groups and artists</td></tr><tr><td>178.8</td><td>Hazardous waste treatment and disposal</td></tr><tr><td>182.20000000000002</td><td>Display advertising</td></tr><tr><td>184.3</td><td>Nonpackaging plastics film and sheet</td></tr><tr><td>187.3</td><td>Books and periodicals</td></tr><tr><td>188.2</td><td>Fruit and vegetable markets</td></tr><tr><td>189</td><td>Boat building</td></tr><tr><td>189.10000000000002</td><td>Other furniture-related products</td></tr><tr><td>190.1</td><td>Precision turned products</td></tr><tr><td>190.60000000000002</td><td>Electricity and signal testing instruments</td></tr><tr><td>192.6</td><td>Telephone answering services</td></tr><tr><td>193.2</td><td>All other textile product mills</td></tr><tr><td>193.9</td><td>Cutlery and hand  ...

-- %% [markdown]
-- 7. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">In January 2021, which industry was the total weekly payroll for production and nonsupervisory employees the highest? Which industry was the lowest?</span>

-- %%
SELECT SUM(j.value) AS 'Total Weekly Payroll', i.industry_name
FROM LaborStatisticsDB.dbo.january_2017 AS j
INNER JOIN LaborStatisticsDB.dbo.industry AS i ON j.id = i.id
INNER JOIN LaborStatisticsDB.dbo.series AS s ON i.industry_code = s.industry_code
WHERE s.data_type_code = 82
GROUP BY i.industry_name
ORDER BY MAX(j.[value]) DESC;

SELECT SUM(j.value) AS 'Total Weekly Payroll', i.industry_name
FROM LaborStatisticsDB.dbo.january_2017 AS j
INNER JOIN LaborStatisticsDB.dbo.industry AS i ON j.id = i.id
INNER JOIN LaborStatisticsDB.dbo.series AS s ON i.industry_code = s.industry_code
WHERE s.data_type_code = 82
GROUP BY i.industry_name
ORDER BY MIN(j.[value]) ASC;
-- Out:
-- (501 rows affected)
-- (501 rows affected)
-- Total execution time: 00:00:00.557
-- <table><tr><th>Total Weekly Payroll</th><th>industry_name</th></tr><tr><td>12934852</td><td>Farm product raw materials</td></tr><tr><td>12657936</td><td>Oil and gas extraction</td></tr><tr><td>4694656</td><td>Semiconductors and electronic components</td></tr><tr><td>5796226.540000001</td><td>NULL</td></tr><tr><td>2174650</td><td>Mail-order houses</td></tr><tr><td>2088448</td><td>Forging and stamping</td></tr><tr><td>2008138</td><td>New car dealers</td></tr><tr><td>1943592</td><td>New single-family general contractors</td></tr><tr><td>1789756</td><td>Financial transaction processing and clearing</td></tr><tr><td>1731240</td><td>Nonresidential property managers</td></tr><tr><td>1725974</td><td>Fruit and vegetable preserving and specialty</td></tr><tr><td>1542446</td><td>Furniture stores</td></tr><tr><td>1481268</td><td>Water and sewer system construction</td></tr><tr><td>1166070</td><td>Other household and institutional furniture</td></tr><tr><td>1120094</td><td>Used household and office goods moving</td></tr><tr><td>1053774</td><td>Other ground passenger transportation</td></tr><tr><td>1032142</td><td>Cosmetic and beauty supply stores</td></tr><tr><td>1018026</td><td>Machinery</td></tr><tr><td>822672</td><td>Marketing consulting services</td></tr><tr><td>812912</td><td>Printing and related support activities</td></tr><tr><td>681878</td><td>Social science and humanities research</td></tr><tr><td>672686</td><td>Basic chemicals</td></tr><tr><td>593226</td><td>Reinsurance carriers</td></tr><tr><td>578852</td><td>Miscellaneous durable goods manufacturing</td></tr><tr><td>497514.24</td><td>Sporting goods</td></tr><tr><td>487372</td><td>Fruits and vegetables</td></tr><tr><td>481915</td><td>Mining</td></tr><tr><td>457038</td><td>Marketing research and public opinion polling</td></tr><tr><td>456842</td><td>Support activities for road transportation</td></tr><tr><td>350360</td><td>Legal services</td></tr><tr><td>331766</td><td>Pulp</td></tr><tr><td>331668</td><td>Computer systems design and related services</td></tr><tr><td>325740</td><td>Lessors of real estate</td></tr><tr><td>321918</td><td>Supermarkets and other grocery stores</td></tr><tr><td>316688</td><td>Siding contractors</td></tr><tr><td>242280</td><td>Gift</td></tr><tr><td>225056</td><td>Office administrative services</td></tr><tr><td>224000</td><td>Waste management and remediation services</td></tr><tr><td>219112</td><td>Plastics packaging materials</td></tr><tr><td>160822</td><td>Architectural and engineering services</td></tr><tr><td>154470</td><td>Farm supplies</td></tr><tr><td>150562</td><td>Crushed and broken limestone mining</td></tr><tr><td>142082</td><td>Home centers</td></tr><tr><td>140052</td><td>Building foundation and exterior contractors</td></tr><tr><td>131286</td><td>Industrial supplies</td></tr><tr><td>112480</td><td>Paper and paper products</td></tr><tr><td>96638</td><td>Automobile dealers</td></tr><tr><td>95700</td><td>Clothing stores</td></tr><tr><td>93848</td><td>Residential building</td></tr><tr><td>81778</td><td>Residential property managers</td></tr><tr><td>73590</td><td>Furniture and home furnishings stores</td></tr><tr><td>71010</td><td>Utility system construction</td></tr><tr><td>70214</td><td>Nondepository credit intermediation</td></tr><tr><td>54804</td><td>Automotive body</td></tr><tr><td>54482</td><td>Other automotive repair and maintenance</td></tr><tr><td>52094</td><td>Fabricated metal products</td></tr><tr><td>46220</td><td>Investment advice</td></tr><tr><td>45774</td><td>Car washes</td></tr><tr><td>45144</td><td>Wood kitchen cabinets and countertops</td></tr><tr><td>38686</td><td>Pharmacies and drug stores</td></tr><tr><td>38438</td><td>Travel agencies</td></tr><tr><td>37882</td><td>Motor vehicles and parts</td></tr><tr><td>37650</td><td>Building finishing contractors</td></tr><tr><td>32776</td><td>Exterminating and pest control services</td></tr><tr><td>31730</td><td>Physical</td></tr><tr><td>31671.76</td><td>Chemicals</td></tr><tr><td>29694< ...
-- <table><tr><th>Total Weekly Payroll</th><th>industry_name</th></tr><tr><td>13.26</td><td>Tile and terrazzo contractors</td></tr><tr><td>13.3</td><td>Gasoline stations</td></tr><tr><td>13.4</td><td>Collection agencies</td></tr><tr><td>5796226.540000001</td><td>NULL</td></tr><tr><td>16.16</td><td>Dairy products</td></tr><tr><td>16.44</td><td>Other plastics products</td></tr><tr><td>16.66</td><td>Framing contractors</td></tr><tr><td>17.38</td><td>Support activities for oil and gas operations</td></tr><tr><td>17.46</td><td>Other heavy construction</td></tr><tr><td>17.5</td><td>Industrial building</td></tr><tr><td>17.52</td><td>Household appliance stores</td></tr><tr><td>17.54</td><td>Wholesale trade agents and brokers</td></tr><tr><td>17.7</td><td>Auto parts</td></tr><tr><td>17.84</td><td>Petroleum and coal products</td></tr><tr><td>17.88</td><td>Offices of real estate agents and brokers</td></tr><tr><td>18.14</td><td>Scientific research and development services</td></tr><tr><td>18.54</td><td>Corrugated and solid fiber boxes</td></tr><tr><td>18.68</td><td>Testing laboratories</td></tr><tr><td>18.78</td><td>Management and technical consulting services</td></tr><tr><td>19.78</td><td>Recyclable materials</td></tr><tr><td>20.02</td><td>Offices of certified public accountants</td></tr><tr><td>21.86</td><td>Other support services</td></tr><tr><td>21.88</td><td>Other financial investment activities</td></tr><tr><td>22.04</td><td>Private service-providing</td></tr><tr><td>22.26</td><td>Electrical contractors</td></tr><tr><td>22.44</td><td>All other motor vehicle parts</td></tr><tr><td>22.68</td><td>Real estate credit</td></tr><tr><td>22.84</td><td>Other miscellaneous durable goods manufacturing</td></tr><tr><td>23.2</td><td>Third-party administration of insurance funds</td></tr><tr><td>24.02</td><td>Remediation and other waste services</td></tr><tr><td>24.04</td><td>Machinery and supplies</td></tr><tr><td>24.16</td><td>Ready-mix concrete</td></tr><tr><td>24.46</td><td>Miscellaneous store retailers</td></tr><tr><td>24.62</td><td>Fossil fuel electric power generation</td></tr><tr><td>25.02</td><td>Transportation equipment</td></tr><tr><td>25.28</td><td>Telecommunications resellers</td></tr><tr><td>25.44</td><td>Electronic instruments</td></tr><tr><td>2409.64</td><td>Durable goods</td></tr><tr><td>25.92</td><td>Newspaper</td></tr><tr><td>26.06</td><td>Broadcasting</td></tr><tr><td>26.22</td><td>Clothing accessories stores</td></tr><tr><td>29.8</td><td>Other personal care services</td></tr><tr><td>30.68</td><td>Transportation and warehousing</td></tr><tr><td>31.48</td><td>Other health and personal care stores</td></tr><tr><td>31.62</td><td>Drywall and insulation contractors</td></tr><tr><td>33.44</td><td>New motor vehicle parts</td></tr><tr><td>35.3</td><td>Turned products and screws</td></tr><tr><td>35.32</td><td>Airport operations</td></tr><tr><td>35.8</td><td>Business associations</td></tr><tr><td>5357.72</td><td>General freight trucking</td></tr><tr><td>37.28</td><td>Seafood product preparation and packaging</td></tr><tr><td>37.32</td><td>General rental centers</td></tr><tr><td>39.14</td><td>Advertising agencies</td></tr><tr><td>39.2</td><td>Cafeterias</td></tr><tr><td>39.4</td><td>Social assistance</td></tr><tr><td>39.6</td><td>Employment services</td></tr><tr><td>39.98</td><td>Hardware stores</td></tr><tr><td>40.94</td><td>Depository credit intermediation</td></tr><tr><td>41.52</td><td>Floor covering stores</td></tr><tr><td>41.62</td><td>Power and communication system construction</td></tr><tr><td>41.92</td><td>Other motor vehicle dealers</td></tr><tr><td>42.06</td><td>Food manufacturing</td></tr><tr><td>42.34</td><td>Lessors of nonresidential buildings</td></tr><tr><td>44.24</td><td>Landscape architectural services</td></tr><tr><td>44.5</td><td>Computer systems design services</td></tr><tr><td>45.64</td><td>Coal mining</td></tr><tr><td>31671.76</td><td>Chemicals</td></tr><tr><td>46.88</td><td>Textile mills</td></tr><tr><td>47.44</td><t ...

-- %% [markdown]
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-numeric: normal; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Subqueries, Unions, Derived Tables, Oh My!</span>
--
-- 1. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">Write a query that returns the series_id, industry_code, industry_name, and value from the january_2017 table but only if that value is greater than the average value for annual_2016 of data_type_code 82.</span>

-- %%
SELECT j.series_id, s.industry_code, i.industry_name, AVG(a.value) AS 'Value'
FROM LaborStatisticsDB.dbo.january_2017 AS j 
INNER JOIN LaborStatisticsDB.dbo.series AS s ON j.series_id = s.series_id
INNER JOIN LaborStatisticsDB.dbo.annual_2016 AS a ON s.series_id = a.series_id
INNER JOIN LaborStatisticsDB.dbo.industry AS i ON a.id = i.id
WHERE s.data_type_code = 82 AND j.value > a.value
GROUP BY s.industry_code;
-- Out:
-- : Msg 8120, Level 16, State 1, Line 1
-- Column 'LaborStatisticsDB.dbo.january_2017.series_id' is invalid in the select list because it is not contained in either an aggregate function or the GROUP BY clause.
-- Total execution time: 00:00:00.061

-- %% [markdown]
-- 2. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">Create a Union table comparing average weekly earnings&nbsp; of production and nonsupervisory employees between annual_16 and january_17 using the data type 30.&nbsp; Round to the nearest penny.&nbsp; You should have a column for the average earnings and a column for the year, and the period.</span>

-- %%
SELECT year, period 
FROM LaborStatisticsDB.dbo.annual_2016 AS a
UNION
SELECT year, period
FROM LaborStatisticsDB.dbo.january_2017 AS j
UNION
SELECT AVG(data_type_code) AS 'Average Weekly Earnings'
FROM LaborStatisticsDB.dbo.series
ORDER BY year;
-- Out:
-- : Msg 205, Level 16, State 1, Line 1
-- All queries combined using a UNION, INTERSECT or EXCEPT operator must have an equal number of expressions in their target lists.
-- Total execution time: 00:00:00.054

-- %% [markdown]
-- ## <span style="font-size:12pt;font-family:Montserrat, sans-serif;color:rgb(53, 74, 95);background-color:rgb(255, 255, 255);font-weight:700;vertical-align:baseline;white-space:pre-wrap;">Summarize Your Results</span>
--
-- <span style="font-size:10pt;font-family:Arvo, serif;color:rgb(102, 102, 102);background-color:rgb(255, 255, 255);vertical-align:baseline;white-space:pre-wrap;">With what you know now about the </span> <span style="background-color:rgb(255, 255, 255);color:rgb(102, 102, 102);font-family:&quot;Times New Roman&quot;;font-size:13.3333px;white-space:pre-wrap;">Bureau of Labor Statistics (BLS) Current Employment Survey (CES) results and working with the</span> <span style="color:rgb(102, 102, 102);white-space:pre-wrap;font-family:&quot;Times New Roman&quot;;font-size:13.3333px;">Labor Statistics Database</span><span style="background-color:rgb(255, 255, 255);color:rgb(102, 102, 102);font-family:Arvo, serif;font-size:10pt;white-space:pre-wrap;">, answer the following questions. Note that while this is subjective, you should include relevant data to back up your opinion.</span>
--
-- 1. <span style="background-color:rgb(255, 255, 255);font-size:10pt;white-space:pre-wrap;color:rgb(102, 102, 102);font-family:Arvo, serif;">During which time period did production and nonsupervisory employees fare better?</span>

-- %% [markdown]
-- Double click here to add your answer

-- %% [markdown]
-- 2. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">In which industries did production and nonsupervisory employees fare better?</span>

-- %% [markdown]
-- Double click here to add your answer.

-- %% [markdown]
-- 3. <span style="font-size: 10pt; font-family: Arvo, serif; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-numeric: normal; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Now that you have explored the datasets, is there any data or information that you wish you had in this analysis?</span>

-- %% [markdown]
-- Double click here to add your answer.
